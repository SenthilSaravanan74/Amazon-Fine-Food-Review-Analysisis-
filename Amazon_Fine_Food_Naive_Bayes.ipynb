# %%
# %matplotlib inline

import sqlite3
import pandas as pd
import numpy as np
import nltk
import string
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer

from sklearn.feature_extraction.text import CountVectorizer
from nltk.stem.porter import PorterStemmer
from sklearn.cross_validation import train_test_split
from sklearn.metrics import accuracy_score
from collections import Counter

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)


# using the SQLite Table to read data.
con = sqlite3.connect('./database.sqlite') 



#filtering only positive and negative reviews i.e. 
# not taking into consideration those reviews with Score=3
filtered_data = pd.read_sql_query("""
SELECT *
FROM Reviews
WHERE Score != 3
""", con) 




# Give reviews with Score>3 a positive rating, and reviews with a score<3 a negative rating.
def partition(x):
    if x < 3:
        return 'negative'
    return 'positive'

#changing reviews with score less than 3 to be positive and vice-versa
actualScore = filtered_data['Score']
positiveNegative = actualScore.map(partition) 
filtered_data['Score'] = positiveNegative

# %%
filtered_data.shape #looking at the number of attributes and size of the data
filtered_data.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator     Score        Time  \
# 0                     1                       1  positive  1303862400
# 1                     0                       0  negative  1346976000
# 2                     1                       1  positive  1219017600
# 3                     3                       3  negative  1307923200
# 4                     0                       0  positive  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %% [markdown]
# Data Cleaning: Deduplication

# %%
display= pd.read_sql_query("""
SELECT *
FROM Reviews
WHERE Score != 3 AND UserId="AR5J8UI46CURR"
ORDER BY ProductID
""", con)
display
# Out:
#        Id   ProductId         UserId      ProfileName  HelpfulnessNumerator  \
# 0   78445  B000HDL1RQ  AR5J8UI46CURR  Geetha Krishnan                     2
# 1  138317  B000HDOPYC  AR5J8UI46CURR  Geetha Krishnan                     2
# 2  138277  B000HDOPYM  AR5J8UI46CURR  Geetha Krishnan                     2
# 3   73791  B000HDOPZG  AR5J8UI46CURR  Geetha Krishnan                     2
# 4  155049  B000PAQ75C  AR5J8UI46CURR  Geetha Krishnan                     2
#
#    HelpfulnessDenominator  Score        Time  \
# 0                       2      5  1199577600
# 1                       2      5  1199577600
# 2                       2      5  1199577600
# 3                       2      5  1199577600
# 4                       2      5  1199577600
#
#                              Summary  \
# 0  LOACKER QUADRATINI VANILLA WAFERS
# 1  LOACKER QUADRATINI VANILLA WAFERS
# 2  LOACKER QUADRATINI VANILLA WAFERS
# 3  LOACKER QUADRATINI VANILLA WAFERS
# 4  LOACKER QUADRATINI VANILLA WAFERS
#
#                                                 Text
# 0  DELICIOUS WAFERS. I FIND THAT EUROPEAN WAFERS ...
# 1  DELICIOUS WAFERS. I FIND THAT EUROPEAN WAFERS ...
# 2  DELICIOUS WAFERS. I FIND THAT EUROPEAN WAFERS ...
# 3  DELICIOUS WAFERS. I FIND THAT EUROPEAN WAFERS ...
# 4  DELICIOUS WAFERS. I FIND THAT EUROPEAN WAFERS ...

# %%
#Sorting data according to ProductId in ascending order
sorted_data=filtered_data.sort_values('ProductId', axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last')

# %%
#Deduplication of entries
final=sorted_data.drop_duplicates(subset={"UserId","ProfileName","Time","Text"}, keep='first', inplace=False)
#final=final.drop_duplicates(subset={"UserId","ProductId","Time"}, keep='first', inplace=False)
final.shape
# Out:
# (364173, 10)

# %%
#Checking to see how much % of data still remains
(final['Id'].size*1.0)/(filtered_data['Id'].size*1.0)*100
# Out:
# 69.25890143662969

# %%
display= pd.read_sql_query("""
SELECT *
FROM Reviews
WHERE Score != 3 AND Id=44737 OR Id=64422
ORDER BY ProductID
""", con)
display
# Out:
#       Id   ProductId          UserId              ProfileName  \
# 0  64422  B000MIDROQ  A161DK06JJMCYF  J. E. Stephens "Jeanne"
# 1  44737  B001EQ55RW  A2V0I904FH7ABY                      Ram
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     3                       1      5  1224892800
# 1                     3                       2      4  1212883200
#
#                                         Summary  \
# 0             Bought This for My Son at College
# 1  Pure cocoa taste with crunchy almonds inside
#
#                                                 Text
# 0  My son loves spaghetti so I didn't hesitate or...
# 1  It was almost a 'love at first bite' - the per...

# %%
final=final[final.HelpfulnessNumerator<=final.HelpfulnessDenominator]

# %%
#Before starting the next phase of preprocessing lets see the number of entries left
print(final.shape)

#How many positive and negative reviews are present in our dataset?
final['Score'].value_counts()
# Out:
# (364171, 10)
# positive    307061
# negative     57110
# Name: Score, dtype: int64

# %%
Data-preprocessing

# %%
# find sentences containing HTML tags
import re

i=0;
for sent in final['Text'].values:
    if (len(re.findall('<.*?>', sent))):
        print(i)
        print(sent)
        break;
    i += 1;
# Out:
# 6
# I set aside at least an hour each day to read to my son (3 y/o). At this point, I consider myself a connoisseur of children's books and this is one of the best. Santa Clause put this under the tree. Since then, we've read it perpetually and he loves it.<br /><br />First, this book taught him the months of the year.<br /><br />Second, it's a pleasure to read. Well suited to 1.5 y/o old to 4+.<br /><br />Very few children's books are worth owning. Most should be borrowed from the library. This book, however, deserves a permanent spot on your shelf. Sendak's best.

# %%
import re

import string
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer

stop = set(stopwords.words('english')) #set of stopwords
sno = nltk.stem.SnowballStemmer('english') #initialising the snowball stemmer

def cleanhtml(sentence): #function to clean the word of any html-tags
    cleanr = re.compile('<.*?>')
    cleantext = re.sub(cleanr, ' ', sentence)
    return cleantext
def cleanpunc(sentence): #function to clean the word of any punctuation or special characters
    cleaned = re.sub(r'[?|!|\'|"|#]',r'',sentence)
    cleaned = re.sub(r'[.|,|)|(|\|/]',r' ',cleaned)
    return  cleaned
print(stop)
print('************************************')
print(sno.stem('tasty'))
# Out:
# {'after', 'at', 'when', 'its', 'but', 'then', 'having', 'hasn', 'been', 'mightn', 'more', 'where', 'should', "don't", 'wasn', 'did', 'him', "you're", "weren't", 'into', 'than', 'mustn', 'won', "wasn't", 'so', 'have', 'all', 'am', 'for', 'own', 'doing', 'while', 'aren', 'she', 'about', 'of', 's', 'do', 'in', 'y', 'hadn', 'itself', 'to', "hadn't", 'himself', 'my', 'other', 'both', 'a', 'shouldn', 'ours', "she's", 'are', 'some', "should've", "wouldn't", 'that', 'o', 've', 'myself', 'whom', "shouldn't", 'wouldn', 'under', 'yours', 'through', 'off', 'again', 'needn', 'i', 'don', 'we', 'ma', 'during', "shan't", 'shan', 'just', 'haven', "isn't", 'with', 'be', 'if', 'out', 'his', 'who', 'being', 'not', "haven't", 'here', 'only', 'they', 'this', 'few', 'd', 'can', 'too', 'he', 'will', 'll', 'below', 'what', 'further', 'and', 'those', 'because', 'themselves', 'your', 'her', 'had', 'until', 'most', 'is', "mustn't", "you'll", 't', 'isn', 'by', 'from', 'yourselves', 'were', 'it', 'above', 'me', 'an', 'ain', 're', 'weren', 'theirs', "mightn't", 'herself', "couldn't", 'against', 'does', 'or', 'on', "hasn't", 'no', 'which', 'the', 'yourself', "aren't", 'm', "needn't", 'was', 'them', 'their', 'same', 'any', 'now', 'before', 'our', 'how', 'each', "you'd", 'up', 'very', "you've", 'couldn', 'doesn', 'hers', 'between', 'down', 'ourselves', 'nor', 'didn', "doesn't", 'as', "didn't", 'once', "that'll", 'why', 'has', 'you', "it's", 'over', 'these', "won't", 'there', 'such'}
# ************************************
# tasti

# %%
#Code for implementing step-by-step the checks mentioned in the pre-processing phase
i=0
str1=' '
final_string=[]
all_positive_words=[] # store words from +ve reviews here
all_negative_words=[] # store words from -ve reviews here.
s=''
for sent in final['Text'].values:
    filtered_sentence=[]
    #print(sent);
    sent=cleanhtml(sent) # remove HTMl tags
    for w in sent.split():
        for cleaned_words in cleanpunc(w).split():
            if((cleaned_words.isalpha()) & (len(cleaned_words)>2)):    
                if(cleaned_words.lower() not in stop):
                    s=(sno.stem(cleaned_words.lower())).encode('utf8')
                    filtered_sentence.append(s)
                    if (final['Score'].values)[i] == 'positive': 
                        all_positive_words.append(s) #list of all words used to describe positive reviews
                    if(final['Score'].values)[i] == 'negative':
                        all_negative_words.append(s) #list of all words used to describe negative reviews reviews
                else:
                    continue
            else:
                continue 
    #print(filtered_sentence)
    str1 = b" ".join(filtered_sentence) #final string of cleaned words
    #print("***********************************************************************")
    
    final_string.append(str1)
    i+=1

# %%
final['CleanedText']=final_string #adding a column of CleanedText which displays the data after pre-processing of the review

# %%
# store final table into an SQlLite table for future.
conn = sqlite3.connect('final.sqlite')
c=conn.cursor()
conn.text_factory = str
final.to_sql('Reviews', conn, flavor=None, schema=None, if_exists='replace', index=True, index_label=None, chunksize=None, dtype=None)

# %% [markdown]
#  Bag of Words (BoW)

# %%
final_df = pd.DataFrame(final) # converting table to a dataframe

# %%
random_final = final_df.sample(n=10000) # Sampling 10k rows 
random_final
# Out:
#             Id   ProductId          UserId  \
# 45938    49985  B00430B73W   AOP5TUC7TTEY0
# 197833  214415  B0037N7GIQ   A40VNMBOUNRLL
# 184240  199851  B001E52VJS  A1ZWIEWLLV1HOG
# 156765  170011  B003VNCRMW   AYYT5ITL86BCW
# 413470  447171  B002CJAOR6   AXRM6XPAUE6IK
# 138792  150623  B000HDHZZI  A1Y2BBN2TXYAOO
# 79072    85977  B000CMKPDI  A2QIB5H8XFUE2U
# 178749  193848  B005IW4WFY  A3QRA8J69DUXFL
# 356723  385851  B000LKZ9KK  A2FCSLMZ98DSZI
# 58810    63887  B004SNMAOO  A148W7XE1Y5D07
# 516906  558866  B000LKX4ZC  A3AIOOMJNJ18QE
# 46516    50601  B000W5N2D0   AR0UK4RH8YIZ8
# 433999  469334  B001E5E24A   ASHCIH6JR66HF
# 176746  191674  B004BS06A6  A1GH22GY2RSGW3
# 175447  190278  B00112GBMM  A213WV5MFQLCBM
# 361167  390617  B0090O3O5K  A3SFIF9B3LDY0S
# 67965    73860  B001E5E3IA  A3V55DVYU80LDS
# 521123  563418  B007JFMH8M   A1RXZ4CABWPVN
# 115569  125334  B001E5E060  A2NPL4ADWSCH91
# 448195  484609  B0000DK4G4  A3JYX9GGUTDVIG
# 131049  142299  B000LKXJW0  A19HJW4VFHB02C
# 461345  498892  B002AN8ME6  A1T7T8POGV5M0T
# 15445    16888  B001LGGH40   A2BCDZO1XQLDH
# 135699  147283  B000GZUBAS   A4POMQP3J286N
# 375334  405855  B003OB0I8G  A1OD9II9H9TEDA
# 164488  178392  B001P1YOGE  A2A0T8MDSB0ZSK
# 495379  535551  B000NV83EG   AF2M7CEQ6RL4O
# 350412  379049  B004NYYJ3I  A2T6ZE7N9P0L3B
# 22538    24661  B001SAYGME  A1DCKHQJ5D3Y2S
# 167931  182071  B0009F3POO   AENBPNKPFDGH3
# ...        ...         ...             ...
# 118058  128058  B000E5SGI4  A3ORZ1TU1NTN51
# 112633  122187  B003YBH1WM  A1L1VOYNHS9NJZ
# 109114  118430  B003VDB79Q  A2I3HFGMA0X35L
# 34113    37118  B002IVDAH4  A3IDWAYAS7QRL8
# 518916  561013  B0012BSMHY  A1EA3QWLRO24X8
# 181906  197281  B000DZG1LY  A1KXNNPZIICB04
# 335452  362961  B0006TN01G  A1ES9BWC8S0CEN
# 396674  428913  B000HNF8ZW   APO0QVCXLAXET
# 65961    71670  B007RTR8AM  A19XE6G6NDZFPS
# 187927  203839  B000VK4CTO  A1EOHC2PPZWFBQ
# 216274  234374  B000F4H5GI  A3QU4LHCO3BFB0
# 128973                                           jimmy                     1
# 175891                               Marie44 "marie44"                    34
# 91743                                     J McGlinchey                     0
# 484086                    Robert T. Brennan "Rob_1970"                     0
# 456152                                           Wrena                     0
# 324686                                    Curt Johnson                     0
# 135602                                         zhuyuan                     0
# 142130                                   T. Jakubowski                     1
# 259205                                   Geeze Us Pete                     6
# 388486                   Christopher Charles Prillwitz                     0
# 283046                                         C. Hill                     0
# 212195                                          DenDen                     0
# 230860                                         Babymom                     0
#
#         HelpfulnessDenominator     Score        Time  \
# 45938                        0  positive  1310774400
# 197833                       1  positive  1317686400
# 184240                       5  positive  1220486400
# 156765                       0  positive  1307318400
# 413470                       2  positive  1324339200
# 138792                       4  positive  1268092800
# 79072                       48  positive  1149206400
# 178749                       1  positive  1341273600
# 356723                       0  positive  1232064000
# 58810                        0  positive  1334966400
# 516906                       0  negative  1311120000
# 46516                        0  positive  1310169600
# 433999                       0  positive  1294358400
# 176746                       0  positive  1318464000
# 175447                       1  positive  1282608000
# 361167                       0  positive  1347753600
# 67965                        3  positive  1253836800
# 521123                       0  positive  1341878400
# 115569                       0  positive  1208649600
# 448195                       2  positive  1225152000
# 131049                       0  positive  1297728000
# 461345                       0  positive  1350432000
# 15445                        1  positive  1235606400
# 135699                       1  positive  1220745600
# 375334                       0  positive  1349308800
# 164488                      11  positive  1264550400
# 495379                       1  positive  1323302400
# 350412                       0  positive  1349827200
# 22538                        0  positive  1300060800
# 167931                       8  positive  1217116800
# ...                        ...       ...         ...
# 118058                       3  positive  1294272000
# 112633                       0  positive  1332201600
# 109114                       0  positive  1346025600
# 34113                        0  positive  1325116800
# 518916                      15  positive  1213833600
# 181906                       1  positive  1213488000
# 335452                       4  positive  1208995200
# 396674                       7  positive  1190419200
# 65961                        0  positive  1343952000
# 187927                       0  positive  1288915200
# 216274                       0  positive  1278115200
# 485594                       0  positive  1271203200
# 253566                       2  negative  1234656000
# 2478                         1  positive  1235520000
# 524080                       1  positive  1276992000
# 411860                       0  positive  1309046400
# 89254                        0  negative  1351123200
# 128973                       1  positive  1321142400
# 175891                      36  positive  1168819200
# 91743                        0  negative  1316217600
# 484086                       0  positive  1289692800
# 456152                       0  negative  1290556800
# 324686                       0  positive  1332720000
# 135602                       0  positive  1314662400
# 142130                       1  positive  1183420800
# 259205                       8  negative  1276387200
# 388486                       2  positive  1156118400
# 283046                       0  positive  1314403200
# 212195                       0  positive  1316563200
# 230860                       0  positive  1335657600
#
#                                                   Summary  \
# 45938                                           great bar
# 197833       Good product, bad packaging on Amazon's part
# 184240                 tasty but too expensive on Amazon!
# 156765                                        Great size!
# 413470                                   Very convenient!
# 138792                                         Good Snack
# 79072                   Zap it before it hits the ground!
# 178749                yummy! except hold the blueberries.
# 356723                                       Best Tasting
# 58810                                                GOOD
# 516906                              Overcooked Soy Crisps
# 46516            The perfect solution for our little dogs
# 433999                       New coffee drinker loves it!
# 176746                       Barely sweet, I like it HOT!
# 470554                                  Shawn J. Burke                     7
# 271725                                       Java Podz                     6
# 437957                                    Happy Always                    10
# 250599                             D. Hughes "Officer"                    28
# 354244                                       C. Porter                     6
# 196107                                    Deb "Debbie"                     4
# 226026                                      Jim Ausman                     5
# 77524                                       J. Knudson                     3
# 420690                     Melanie Jarrard "tea lover"                     1
# 226066                                      J. A. Ward                     0
# 33240                                             Bobs                     0
# 155411                     Richard Stephens "richinal"                     0
# 45267                       Rae L. Bruso "Rae Glispin"                    10
# 197329                                 Robert D. Clark                     5
# ...                                                ...                   ...
# 403987                                       J. Gerald                     0
# 310005                                Darrell Dizoglio                     0
# 446304                                           Ralph                     0
# 17733                                               J.                     0
# 181844                                Katherine Graham                     0
# 339465                                             Jay                     0
# 484365                                           Rod B                     0
# 504119                                         Ophelia                     0
# 176055                                      FPD Junior                     0
# 386811                                 T. Meadows "TM"                     0
# 89254   notAyesperson "Always in search of good books"                     0
# 316677                                         Shaedon                     0
# 47689                                           Holdel                     0
# 83375                                            JENNY                     0
# 258448       Bohemian Bon Vivant "Bohemian Bon Vivant"                     0
# 417532                                    Jason Golomb                     0
# 472858                                       Tyler J M                     0
# 482235                   Mitchell M. Tse "mitchelltse"                     0
# 111766                                           jilly                     0
# 486644                                  M.G. "MNaples"                     0
# 5661                                          M.A.M.B.                     0
# 275846                               Hubert Farnsworth                     0
# 355771                                 K. Woodhall "k"                     0
# 319733                                          wejani                     0
# 55100                   Cecelia Thomas "Lady Kinrowan"                     0
# 468409                                Eugene M. Watson                     0
# 75382                              zena3546 "zena3546"                     0
# 444867                                      D. Brennan                     0
# 469195                                       Christine                     0
# 214905                                            Lahn                     0
#
#         HelpfulnessDenominator     Score        Time  \
# 70688                        0  positive   948672000
# 346114                       2  positive  1013385600
# 409953                       1  positive  1068076800
# 152806                      31  positive  1073088000
# 401781                       5  positive  1073865600
# 458134                       5  positive  1080432000
# 10116                        0  positive  1081209600
# 502450                       0  positive  1083715200
# 5886                         0  positive  1091059200
# 24069                        4  positive  1092009600
# 138676                      72  positive  1096416000
# 189015                       0  positive  1102118400
# 514252                       5  positive  1102809600
# 73146                        6  positive  1105833600
# 392482                       6  positive  1106179200
# 489672                       4  positive  1107561600
# 470554                       9  positive  1107907200
# 271725                       6  positive  1108944000
# 437957                      12  positive  1111190400
# 250599                      30  positive  1111708800
# 354244                       6  positive  1113177600
# 196107                       6  negative  1114992000
# 226026                       5  positive  1116201600
# 77524                        3  positive  1116979200
# 420690                       1  positive  1118275200
# 226066                       1  positive  1119225600
# 33240                        0  positive  1123545600
# 155411                       0  positive  1124755200
# 45267                       10  positive  1125360000
# 197329                       5  positive  1125878400
# ...                        ...       ...         ...
# 403987                       0  positive  1351036800
# 310005                       0  positive  1351036800
# 446304                       0  positive  1351036800
# 17733                        0  positive  1351036800
# 181844                       0  positive  1351123200
# 339465                       0  positive  1351123200
# 484365                       0  positive  1351123200
# 504119                       0  negative  1351123200
# 176055                       0  positive  1351123200
# 386811                       0  positive  1351123200
# 89254                        0  negative  1351123200
# 316677                       0  positive  1351123200
# 47689                        0  positive  1351123200
# 83375                        0  negative  1351123200
# 258448                       0  positive  1351123200
# 417532                       0  positive  1351123200
# 472858                       0  positive  1351123200
# 482235                       0  positive  1351123200
# 111766                       0  positive  1351123200
# 486644                       0  positive  1351123200
# 5661                         0  positive  1351123200
# 275846                       0  negative  1351209600
# 355771                       0  positive  1351209600
# 319733                       0  positive  1351209600
# 55100                        0  positive  1351209600
# 468409                       0  positive  1351209600
# 75382                        0  positive  1351209600
# 444867                       0  negative  1351209600
# 469195                       0  positive  1351209600
# 214905                       0  positive  1351209600
#
#                                                   Summary  \
# 70688                              A sure death for flies
# 346114                       A little gross, a lot of fun
# 409953                                Righteous Hot Sauce
# 152806              One of the great cheeses of the world
# 401781                              The Best Cuban Coffee
# 458134                               The REAL Maple Syrup
# 10116   Best coffee I've tasted. I try others but alwa...
# 502450                      The best coco I have ever had
# 5886                                          Great food!
# 24069                  Most excellent carbonated beverage
# 138676  Read it once. Read it twice. Reading Chicken S...
# 189015                                  Kenyan Breakfast.
# 514252                      There are no better Madelenes
# 73146                                        Fabulous Tea
# 392482                                       YUMMY Candy!
# 489672                   Relish is good price is too high
# 470554        Awesome Chocolate!!!!!!!!!!!!!!!!!!!!!!!!!!
# 271725                   Review from singleserveoffee.com
# 437957  Wonderful green tea with a most enjoyable afte...
# 250599                           Nice little fukien tree!
# 354244                           My favorite coffee maker
# 196107                                          Very Weak
# 226026            The Best Canned Tuna I Have Ever Tasted
# 77524                                        A Texas must
# 420690                                           Amazing!
# 226066                          So Good and Good fro You!
# 33240                                            Hot item
# 155411                             I prefer mild roast...
# 45267         Expect the golf ball chocolates to be small
# 197329                                  A cheesey comment
# ...                                                   ...
# 403987                        good product, small package
# 310005  Best taste, value and nutrition in a natural v...
# 446304                                         REAL DEAL!
# 17733                               Pure Matcha Green Tea
# 181844                                    Almost Perfect!
# 339465                                      Excellent Tea
# 484365                               Lean Treats are good
# 504119                     very clean!  sweet nutty taste
# 176055                     Dat'l Do It spicy Pepper Sauce
# 386811                                     Best out there
# 89254                                                Nope
# 316677                           Exactly what I paid for!
# 47689                                  Always a huge hit!
# 83375                                                Cute
# 258448                               Fantastic -- But ...
# 417532          Deliciously Rich Diet Peanut Butter Treat
# 472858                            TASTY!! FAST SHIPPING!!
# 482235                         A great caffeine-free tea!
# 111766                             Great for my older cat
# 486644                                   Sweet Perfection
# 5661                                            Very good
# 275846                  Super healthy but tastes like ass
# 355771                           a great product and deal
# 319733                                 Great Hot Cider!!!
# 55100   Butler's chocolate is the real deal direct fro...
# 468409                                       Great Salmon
# 75382                                       Great product
# 444867                                       Buyer beware
# 469195                                    BEST GRAVY EVER
# 214905                             Can't live without it!
#
#                                                      Text  \
# 70688   I bought a few of these after my apartment was...
# 346114  Michael Keaton was already on his way to being...
# 401781  b'also live exil san francisco loyal miami roo...
# 458134  b'product coomb farm pantri year mapl syrup ta...
# 10116   b'like strong smooth flavor coffe tri other ke...
# 502450               b'enjoy hot coco must say best ever'
# 5886    b'version ground current cat favorit version r...
# 24069   b'one thing miss austin littl soft drink orang...
# 138676  b'day person say chicken soup theyr probabl go...
# 189015  b'introduc kenya india settler name cain nowad...
# 514252  b'donsuemor madelein absolut delici compani cu...
# 73146   b'first pick tea pari bon march depart store f...
# 392482  b'employ wonder friend stumbl across yummi can...
# 489672  b'fantast relish mix cream chees realli good d...
# 470554  b'chocol lover must experi chocol custom servi...
# 271725  b'one caught surpris dont know pod maker flavo...
# 437957  b'surpris good tea great price best part tast ...
# 250599  b'arriv perfect condit trunk beauti train shap...
# 354244  b'coffe maker great husband friend two differ ...
# 196107  b'java podz coffe pad fit well senseo coffe ma...
# 226026  b'huge tuna fan eat least three time week use ...
# 77524   b'soda grew pepper great tast noth say texa be...
# 420690  b'recent tri tea effect absolut amaz probabl f...
# 226066  b'becom favorit ice tea full flavor especi spe...
# 33240   b'bulk paprika black cloud loom food industri ...
# 155411  b'still pretti darn good senseo favorit way st...
# 45267   b'chocol great idea golf leagu banquet grab gi...
# 197329  b'excel tast partook said much better four far...
# ...                                                   ...
# 403987  b'tasti crunchi granola well made ounc packag ...
# 310005  b'year user gayelord hauser natur veget broth ...
# 446304  b'true juic ad delici drink acai pretti much e...
# 17733   b'realli like matcha green tea ive tri organ b...
# 181844  b'want perfect result year search organ alo dr...
# 339465  b'best tea yet remind fine wine smooth full bo...
# 484365  b'dog love arriv fresh soft weve tri treat con...
# 504119  b'sure realli realli clean wash coupl hundr gr...
# 176055  b'sauc hot tasti spici much hotter datil peppe...
# 386811  b'realli hard find area buy big bottl south de...
# 89254   b'like threw away thin slice marlin cover suga...
# 316677  b'receiv vanilla bean quick vacuum seal packag...
# 47689   b'amaz hit drizzl stock chees dip recip come c...
# 83375   b'reason thought got three pop get one price p...
# 258448  b'fantast stuff favorit flavor fabriqu make ho...
# 417532  b'food miss diet peanut butter walk bright col...
# 472858  b'well year sinc purchas eel sauc amazon make ...
# 482235  b'like everyth lipton blackberri vanilla herba...
# 111766  b'older cat stop eat dri kibbl food month ago ...
# 486644  b'everyth world perfect realli perfect candi d...
# 5661    b'tast delisi work efect drink rigth time lean...
# 275846  b'idea peopl think say stuff tast great must w...
# 355771  b'look review shop around local buy local best...
# 319733  b'hard find much anyth sugarfre realli tast go...
# 55100   b'nifti hot chocol disc ad warm milk milk alte...
# 468409  b'salmon best tri make small varieti salmon di...
# 75382   b'wonder flour use low carb full nutrient dont...
# 444867  b'nespresso make great coffe great machin swit...
# 469195  b'love gravi mix quick meal worth price realli...
# 214905  b'french liter grew salt dont even know cook w...
#
# [10000 rows x 11 columns]

# %%
#BoW
count_vect = CountVectorizer() 
final_counts = count_vect.fit_transform(random_final['CleanedText'].values)

# %%
type(final_counts) # sparse matrix
# Out:
# scipy.sparse.csr.csr_matrix

# %%
final_counts.get_shape() # shape of matrix after Vectorizing
# Out:
# (10000, 13067)

# %%
# Standardizing the data with mean = 0 and std.dev = 1
from sklearn.preprocessing import StandardScaler
standardized_data = StandardScaler(with_mean=False).fit_transform(final_counts)
print(standardized_data.shape)
# Out:
# (10000, 13067)
# /home/shebu/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
X = standardized_data.toarray() # converting the standardized data to dense array
y = np.array(random_final['Score']) # converting Review attribute to a numpy array

# %%
from sklearn.model_selection import train_test_split

# split the data set into train and test 70% train and 30% test 
X1, X_test, y1, y_test = train_test_split(X, y, test_size=0.3, shuffle=False, random_state=0)

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import cross_val_score
from sklearn.naive_bayes import BernoulliNB
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import GridSearchCV
                               
tss = TimeSeriesSplit(n_splits=10) # TimeSeries Split with number of splits=10
N_BB = BernoulliNB() # applying Bernoulli Naive-Bayes

a = np.logspace(0.0, 10.0, num=50, base=1.25) # specifying the range of the hyperparameter alpha for GridSearch

NB_params = {'alpha':a} # hyperparameter to choose  

# GridSearch for finding right hyperparameter with with 10 fold CV on TimeSeriesSplit
gcv = GridSearchCV(N_BB, NB_params,cv=tss, refit=True) 

# Fit the training data
gcv.fit(X1, y1)

# find the mean score for Cross-Validation using 10 Fold Time Series CV after finding the right hyperparameter 
score_BOW = cross_val_score(gcv, X=X1, y=y1, cv=tss).mean()
print(score_BOW)
# Out:
# 0.8419811320754716

# %%
gcv.best_params_  # print the best hyperparameter alpha
# Out:
# {'alpha': 9.313225746154785}

# %%
from sklearn.metrics import recall_score, f1_score, confusion_matrix, accuracy_score, precision_score


# instantiate learning model for best alpha
N_BB_op = BernoulliNB(alpha=9.313225746154785)

# fitting the model
N_BB_op.fit(X1, y1)

# predict the response
pred_NB = N_BB_op.predict(X_test)

# print top 20 features for each class for BOW
print("Top 20 Positive Features for BOW and Top 20 Negative Features for BOW ")
print("\n\n")

# defining a function for finding the top features of each class
def top_most_features(vectorizer, clf, n=20):
    feature_names = vectorizer.get_feature_names() # getting all the feature names
    coefs_with_fns = sorted(zip(clf.coef_[0], feature_names)) # retrieve the coefficient & sort them based on values 
    top = zip(coefs_with_fns[:n], coefs_with_fns[:-(n + 1):-1]) 
    for (coef_1, fn_1), (coef_2, fn_2) in top:
        print ("\t%-15s\t%.4f\t%-15s\t\t%-15s\t%.4f\t%-15s" % (fn_2, coef_1, 'positive', fn_1, coef_2, 'negative'))

        
top_most_features(count_vect, N_BB_op)

print()

# evaluate various performance measures:
print("Accuracy = ",accuracy_score(y_test, pred_NB)) # accuracy
print("Confusion Matrix\n", confusion_matrix(y_test, pred_NB)) # Confusion Matrix
tn, fn, fp, tp = confusion_matrix(y_test, pred_NB).ravel() # tn, fn, fp, tp
print("(tn, fn, fp, tp) =",(tn, fn, fp, tp))
print("Recall = ",recall_score(y_test, pred_NB, pos_label='positive')) # Recall
print("f1-Score = "  ,f1_score(y_test, pred_NB, pos_label='positive')) # f1-Score
print("Precision = ",precision_score(y_test, pred_NB, pos_label='positive'))# Precision
# Out:
# Top 20 Positive Features for BOW and Top 20 Negative Features for BOW
#
#
#
# 	like           	-6.4548	positive       		aaaaaahhhhh    	-1.1674	negative
# 	tast           	-6.4548	positive       		aaah           	-1.2067	negative
# 	love           	-6.4548	positive       		aafco          	-1.2192	negative
# 	great          	-6.4548	positive       		aamzon         	-1.2453	negative
# 	good           	-6.4548	positive       		abbazabba      	-1.2769	negative
# 	flavor         	-6.4548	positive       		abbrevi        	-1.4353	negative
# 	use            	-6.4548	positive       		abc            	-1.4707	negative
# 	tri            	-6.4548	positive       		abhor          	-1.5158	negative
# 	product        	-6.4548	positive       		abnorm         	-1.5220	negative
# 	one            	-6.4548	positive       		abomin         	-1.5251	negative
# 	make           	-6.4548	positive       		abouy          	-1.6025	negative
# 	get            	-6.4548	positive       		abras          	-1.6947	negative
# 	buy            	-6.4548	positive       		absurt         	-1.8768	negative
# 	time           	-6.4548	positive       		acaia          	-1.8823	negative
# 	find           	-6.4548	positive       		acana          	-1.9266	negative
# 	would          	-6.4548	positive       		acceler        	-1.9382	negative
# 	amazon         	-6.4548	positive       		accent         	-1.9500	negative
# 	realli         	-6.4548	positive       		accommod       	-1.9790	negative
# 	best           	-6.4548	positive       		accourd        	-2.0150	negative
# 	price          	-6.4548	positive       		accuraci       	-2.0214	negative
#
# Accuracy =  0.8393333333333334
# Confusion Matrix
#  [[   3  474]
#  [   8 2515]]
# (tn, fn, fp, tp) = (3, 474, 8, 2515)
# Recall =  0.996829171621086
# f1-Score =  0.9125544267053701
# Precision =  0.8414185346269656

# %% [markdown]
#  TF-IDF

# %%
# Taking Tf-idf bigram and vectorizing it
tf_idf_vect = TfidfVectorizer(ngram_range=(1,2))
final_tf_idf = tf_idf_vect.fit_transform(random_final['CleanedText'].values)

# %%
final_tf_idf.get_shape() # Shape of tf-idf vectorizer
# Out:
# (10000, 236244)

# %%
# Standardizing the data with mean=0 and std.dev=1
from sklearn.preprocessing import StandardScaler
standardized_data_tf = StandardScaler(with_mean=False).fit_transform(final_tf_idf)
print(standardized_data_tf.shape)
# Out:
# (10000, 400)

# %%
X_tf = standardized_data_tf.toarray() # storing the values after standardization in a dense array
y_tf = np.array(random_final['Score']) # storing the values of Scores in numpy array

# %%
# split the data set into train and test, 70% train and 30% test 
from sklearn.model_selection import train_test_split

X2, X_test2, y2, y_test2 = train_test_split(X_tf, y_tf, test_size=0.3, shuffle=False, random_state=0)

# %%
from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import cross_val_score
from sklearn.naive_bayes import BernoulliNB
from sklearn.model_selection import cross_val_predict
from sklearn.model_selection import GridSearchCV
                               
tss_tf = TimeSeriesSplit(n_splits=10) # TimeSeries Split with number of splits=10
N_BB_tf = BernoulliNB()  # applying Bernoulli Naive-Bayes

atf = np.logspace(0.0, 10.0, num=50, base=1.25) # specifying the range of the hyperparameter alpha for GridSearch

NB_params_tf = {'alpha':atf} # hyperparameter to choose  

# GridSearch for finding right hyperparameter with with 10 fold CV on TimeSeriesSplit
gcv_tf = GridSearchCV(N_BB_tf, NB_params_tf,cv=tss_tf, refit=True)

# Fit the training data
gcv_tf.fit(X2, y2)

# find the mean score for Cross-Validation using 10 Fold Time Series CV after finding the right hyperparameter 
score_tf = cross_val_score(gcv_tf, X=X2, y=y2, cv=tss_tf).mean()
print(score_tf)
# Out:
# 0.8641509433962264

# %%
gcv_tf.best_params_  # print the best hyperparameter alpha
# Out:
# {'alpha': 1.0953555355153197}

# %%
from sklearn.metrics import recall_score, f1_score, confusion_matrix, accuracy_score, precision_score


# instantiate learning model for best alpha
N_BB_op_tf = BernoulliNB(alpha=1.0953555355153197)

# fitting the model
N_BB_op_tf.fit(X2, y2)

# predict the response
pred_NB_tf = N_BB_op_tf.predict(X_test2)


# print top 20 features for each class for tf-idf
print("Top 20 Positive Features for Tf-idf and Top 20 Negative Features for Tf-idf ")
print("\n\n")


# defining a function for finding the top features of each class
def show_most_informative_features(vectorizer, clf, n=20):
    feature_names = vectorizer.get_feature_names()  # getting all the feature names
    coefs_with_fns = sorted(zip(clf.coef_[0], feature_names)) # retrieve the coefficient & sort them based on values 
    top = zip(coefs_with_fns[:n], coefs_with_fns[:-(n + 1):-1])
    for (coef_1, fn_1), (coef_2, fn_2) in top:
        print ("\t%-10s\t%.4f\t%-15s\t\t%-10s\t%.4f\t%-15s" % (fn_2, coef_1, 'positive', fn_1, coef_2, 'negative'))
                


show_most_informative_features(tf_idf_vect, N_BB_op_tf)

print()

# evaluate various performance measures:
print("Accuracy = ",accuracy_score(y_test2, pred_NB_tf))# accuracy
print("Confusion Matrix\n", confusion_matrix(y_test2, pred_NB_tf))# Confusion matrix
tn, fn, fp, tp = confusion_matrix(y_test2, pred_NB_tf).ravel()# tn, fn, fp, tp
print("(tn, fn, fp, tp) =",(tn, fn, fp, tp))
print("Recall = ",recall_score(y_test2, pred_NB_tf, pos_label='positive')) # Recall
print("f1-Score = "  ,f1_score(y_test2, pred_NB_tf, pos_label='positive')) # f1-score
print("Precision = ",precision_score(y_test2, pred_NB_tf, pos_label='positive'))# precision
# Out:
# Top 20 Positive Features for Tf-idf and Top 20 Negative Features for Tf-idf
#
#
#
# 	aback two 	-1.3274	positive       		aaf came  	-0.6145	negative
# 	abl bing  	-1.2924	positive       		aaf       	-0.6417	negative
# 	abdomin fat	-0.9962	positive       		aafco     	-0.6533	negative
# 	abl sampl 	-0.7930	positive       		abamectin fipronil	-0.6624	negative
# 	absolut real	-0.7870	positive       		aafco requir	-0.6631	negative
# 	abil mani 	-0.7723	positive       		abel      	-0.6631	negative
# 	abl focus 	-0.7654	positive       		abil make 	-0.6634	negative
# 	abl coffe 	-0.7632	positive       		abil choos	-0.6644	negative
# 	abil adjust	-0.7549	positive       		aaa       	-0.6657	negative
# 	abid seem 	-0.7539	positive       		abi       	-0.6667	negative
# 	absolut must	-0.7471	positive       		abl digest	-0.6670	negative
# 	absolut ador	-0.7456	positive       		aback first	-0.6690	negative
# 	acai mix  	-0.7449	positive       		abdomin   	-0.6696	negative
# 	absolut bless	-0.7442	positive       		abl fulli 	-0.6696	negative
# 	abl get   	-0.7439	positive       		abl carri 	-0.6700	negative
# 	absolutey 	-0.7378	positive       		abl add   	-0.6703	negative
# 	abnorm    	-0.7371	positive       		abil synthes	-0.6703	negative
# 	abandon bad	-0.7368	positive       		aback     	-0.6703	negative
# 	abhor sin 	-0.7361	positive       		aardvark although	-0.6716	negative
# 	abl guess 	-0.7350	positive       		abil easili	-0.6726	negative
#
# Accuracy =  0.866
# Confusion Matrix
#  [[ 184  334]
#  [  68 2414]]
# (tn, fn, fp, tp) = (184, 334, 68, 2414)
# Recall =  0.9726027397260274
# f1-Score =  0.9231357552581262
# Precision =  0.8784570596797671
